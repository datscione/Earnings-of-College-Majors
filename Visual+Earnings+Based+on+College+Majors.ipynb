# %% [markdown]
# Guided Project: Visualizing Earnings Based om College Majors

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = 173
recent_grads = recent_grads.dropna()
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  172.000000   172.000000     172.000000     172.000000     172.000000
# mean    87.377907  3895.953488   39370.081395   16723.406977   22646.674419
# std     49.983181  1679.240095   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.750000  2403.750000    4549.750000    2177.500000    1778.250000
# 50%     87.500000  3608.500000   15104.000000    5434.000000    8386.500000
# 75%    130.250000  5503.250000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size      Employed      Full_time      Part_time  \
# count  172.000000   172.000000     172.00000     172.000000     172.000000
# mean     0.522223   357.941860   31355.80814   26165.767442    8877.232558
# ...

# %% [markdown]
# One row has been dropeed, i.e. one row had missing values.

# %%
cleaned_data_count = 172

# %%
ax1 = recent_grads.plot(x='Sample_size', y='Median', kind='scatter', title='Sample Size vs Median')

# %%
ax2= recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter', title='Sample Size vs Unemployment Rate')

# %%
ax3 = recent_grads.plot(x='Full-time', y='Median', kind='scatter')
ax3.set_title('Full-time vs Median')
# Out:
# KeyErrorTraceback (most recent call last)
# /dataquest/system/env/python3/lib/python3.4/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Full-time'
#
# During handling of the above exception, another exception occurred:
#
# KeyErrorTraceback (most recent call last)
# <ipython-input-11-0f520ac5fbe6> in <module>()
# ----> 1 ax3 = recent_grads.plot(x='Full-time', y='Median', kind='scatter')
#       2 ax3.set_title('Full-time vs Median')
#
# ...

# %%
ax4= recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter', title='Share Women vs Unemployment Rate')

# %%
ax2= recent_grads.plot(x='Men', y='Median', kind='scatter', title='Men vs Median')

# %%
ax2= recent_grads.plot(x='Women', y='Median', kind='scatter', title='Women vs Median')

# %% [markdown]
# Students in more popular majors do not make more money. As men increases or as women increases, the median does not increase. Students that majored in subjects that were majority female did not make more money.

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000))

# %%
recent_grads['Median'].value_counts()

# %%
recent_grads['Median'].value_counts().tail()

# %%
recent_grads['Median'].value_counts().sort_index()

# %%
cols = ['Sample_size', 'Median', 'Employed', 'Full_time', 'ShareWomen', 'Unemployment_rate', 'Men', 'Women']

fig = plt.figure(figsize=(5,12))
for r in range(0, 4):
    ax = fig.add_subplot(4,1,r+1)
    ax = recent_grads[cols[r]].plot(kind='hist').set_title(cols[r])

# %%
cols = ['Sample_size', 'Median', 'Employed', 'Full_time', 'ShareWomen', 'Unemployment_rate', 'Men', 'Women']

fig = plt.figure(figsize=(5,12))
for r in range(4,8):
    ax = fig.add_subplot(4,1,r-3)
    ax = recent_grads[cols[r]].plot(kind='hist').set_title(cols[r])

# %% [markdown]
# 67% (2/3) of majors are predominantly female. 33% are male. The most common median salary range is 30,000-40,000.

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(7,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd175bb46a0>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(10,10))
plt.show()

# %% [markdown]
# We see the most common median salary is about 35000.

# %%
scatter_matrix(recent_grads[['Men', 'Women']], figsize=(10,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd17544bb00>,
# ...
#       dtype=object)

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[-10:]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %% [markdown]
# The percentages of women in the last ten rows of the recent_grads dataframe is much higher. The percentage of women who majored in the science and engineering fields in the first ten rows is much lower than the percentage of women who majored in other subjects represented in the last ten rows.

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate')

# %% [markdown]
# The unemployment rate is more varied in the science and engineering fields in the first ten rows than in the fields represented in the last ten rows.
